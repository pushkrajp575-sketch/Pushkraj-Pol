# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydotplus

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd



sana = pd.read_csv("Indian_Employee_Data.csv")

# %%
sana.head()
# Out:
#   Employee_ID          Name   Age  Gender   Department           Position  \
# 0      EMP001  Rajesh Kumar  32.0    Male  Engineering   Senior Developer
# 1      EMP002  Priya Sharma  28.0  Female    Marketing  Marketing Manager
# 2      EMP003    Amit Singh  35.0    Male      Finance  Financial Analyst
# 3      EMP004   Sneha Patel  26.0  Female          NaN       HR Executive
# 4      EMP005  Vikram Reddy  40.0    Male  Engineering          Tech Lead
#
#       Salary  Experience_Years       City        State Education  \
# 0   850000.0               8.0  Bangalore    Karnataka    B.Tech
# 1   720000.0               5.0     Mumbai  Maharashtra       MBA
# 2   650000.0              10.0      Delhi        Delhi        CA
# 3   480000.0               3.0  Ahmedabad      Gujarat       MBA
# 4  1200000.0              15.0  Hyderabad    Telangana    M.Tech
#
#    Performance_Rating Joining_Date  Projects_Completed  Overtime_Hours
# ...

# %%
sana.tail()
# Out:
#    Employee_ID          Name   Age  Gender Department              Position  \
# 44      EMP045   Neha Kapoor  28.0  Female         IT          Data Analyst
# 45      EMP046   Amit Sharma  27.0    Male         IT      Junior Developer
# 46      EMP047    Riya Gupta  32.0  Female         HR         HR Specialist
# 47      EMP048  Rohit Bansal  36.0    Male    Finance        Senior Analyst
# 48      EMP049  Sneha Tiwari  25.0  Female      Sales  Sales Representative
#
#       Salary  Experience_Years       City        State Education  \
# 44       NaN               4.0  Bangalore    Karnataka      M.Sc
# 45  650000.0               4.0      Delhi          NaN    B.Tech
# 46       NaN               8.0     Mumbai  Maharashtra       MBA
# 47  980000.0              12.0     Mumbai  Maharashtra        CA
# 48       inf               2.0    Kolkata  West Bengal     B.Com
#
#     Performance_Rating Joining_Date  Projects_Completed  Overtime_Hours
# ...

# %%
sana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         49 non-null     object
#  1   Name                49 non-null     object
#  2   Age                 47 non-null     float64
#  3   Gender              49 non-null     object
#  4   Department          48 non-null     object
#  5   Position            48 non-null     object
#  6   Salary              44 non-null     float64
#  7   Experience_Years    47 non-null     float64
#  8   City                49 non-null     object
#  9   State               46 non-null     object
#  10  Education           49 non-null     object
#  11  Performance_Rating  45 non-null     float64
#  12  Joining_Date        48 non-null     object
#  13  Projects_Completed  48 non-null     float64
#  14  Overtime_Hours      48 non-null     float64
# dtypes: float64(6), object(9)
# ...

# %%
sana.shape
# Out:
# (49, 15)

# %%
sana.dtypes
# Out:
# Employee_ID            object
# Name                   object
# Age                   float64
# Gender                 object
# Department             object
# Position               object
# Salary                float64
# Experience_Years      float64
# City                   object
# State                  object
# Education              object
# Performance_Rating    float64
# Joining_Date           object
# Projects_Completed    float64
# Overtime_Hours        float64
# dtype: object

# %%
sana.isnull()
# Out:
#     Employee_ID   Name    Age  Gender  Department  Position  Salary  \
# 0         False  False  False   False       False     False   False
# 1         False  False  False   False       False     False   False
# 2         False  False  False   False       False     False   False
# 3         False  False  False   False       False     False   False
# 4         False  False  False   False       False     False   False
# 5         False  False  False   False       False     False   False
# 6         False  False  False   False       False     False   False
# 7         False  False  False   False       False     False   False
# 8         False  False  False   False       False     False   False
# 9         False  False  False   False       False     False   False
# 10        False  False  False   False       False     False   False
# 11        False  False   True   False       False     False   False
# 12        False  False  False   False       False     False   False
# ...

# %%
sana.isnull().sum()
# Out:
# Employee_ID           0
# Name                  0
# Age                   2
# Gender                0
# Department            1
# Position              1
# Salary                5
# Experience_Years      2
# City                  0
# State                 3
# Education             0
# Performance_Rating    4
# Joining_Date          1
# Projects_Completed    1
# Overtime_Hours        1
# dtype: int64

# %%
sana['Department'].fillna(sana['Department'].mode()[0],inplace=True)

# %%
sana['Position'].fillna(sana['Position'].mode()[0],inplace=True)

# %%
sana['Performance_Rating'].fillna(sana['Performance_Rating'].mean(),inplace=True)

# %%
sana['Overtime_Hours'].fillna(sana['Overtime_Hours'].mode()[0],inplace=True)

# %%
sana.isnull().sum()
# Out:
# Employee_ID           0
# Name                  0
# Age                   2
# Gender                0
# Department            0
# Position              0
# Salary                5
# Experience_Years      2
# City                  0
# State                 3
# Education             0
# Performance_Rating    0
# Joining_Date          1
# Projects_Completed    1
# Overtime_Hours        0
# dtype: int64

# %%
sana['Monthly Salary'].fillna(sana['Monthly Salary'].mean(), inplace=True)

# %%
sana.drop_duplicates()
# Out:
#    Employee_ID            Name        Age  Gender   Department  \
# 0       EMP001    Rajesh Kumar  32.000000    Male  Engineering
# 1       EMP002    Priya Sharma  28.000000  Female    Marketing
# 2       EMP003      Amit Singh  35.000000    Male      Finance
# 3       EMP004     Sneha Patel  26.000000  Female           IT
# 4       EMP005    Vikram Reddy  40.000000    Male  Engineering
# 5       EMP006      Kavya Nair  29.000000  Female        Sales
# 6       EMP007     Arjun Gupta  31.000000    Male  Engineering
# 7       EMP008     Meera Joshi  27.000000  Female       Design
# 8       EMP009   Rohit Agarwal  33.000000    Male      Finance
# 9       EMP010     Anita Verma  38.000000  Female           HR
# 10      EMP011     Suresh Iyer  42.000000    Male  Engineering
# 11      EMP012  Pooja Malhotra  32.914894  Female    Marketing
# 12      EMP013    Karan Chopra  30.000000    Male        Sales
# 13      EMP014       Divya Rao  34.000000  Female  Engineering
# ...

# %%
sana.rename(columns = {"Salary":"Monthly Salary"},inplace=True)
sana.fillna(sana.mean(numeric_only=True),inplace=True)

# %%
sana.head()
# Out:
#   Employee_ID          Name   Age  Gender   Department           Position  \
# 0      EMP001  Rajesh Kumar  32.0    Male  Engineering   Senior Developer
# 1      EMP002  Priya Sharma  28.0  Female    Marketing  Marketing Manager
# 2      EMP003    Amit Singh  35.0    Male      Finance  Financial Analyst
# 3      EMP004   Sneha Patel  26.0  Female           IT       HR Executive
# 4      EMP005  Vikram Reddy  40.0    Male  Engineering          Tech Lead
#
#    Monthly Salary  Experience_Years       City        State Education  \
# 0        850000.0               8.0  Bangalore    Karnataka    B.Tech
# 1        720000.0               5.0     Mumbai  Maharashtra       MBA
# 2        650000.0              10.0      Delhi        Delhi        CA
# 3        480000.0               3.0  Ahmedabad      Gujarat       MBA
# 4       1200000.0              15.0  Hyderabad    Telangana    M.Tech
#
#    Performance_Rating Joining_Date  Projects_Completed  Overtime_Hours
# ...

# %%
sana.fillna(sana.mean(numeric_only=True),inplace=True)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Replace infinity values with NaN
sana["Monthly Salary"].replace([np.inf, -np.inf], np.nan, inplace=True)

# Fill missing values using Mean
sana["Monthly Salary"].fillna(
    sana["Monthly Salary"].mean(),
    inplace=True
)

# OR, if sir asked to use Mode instead of Mean, use this:
# sana["Monthly Salary"].fillna(
#     sana["Monthly Salary"].mode()[0],
#     inplace=True
# )

# Create scaler object
scaler = StandardScaler()

# Apply Standard Scaling
sana["Monthly Salary"] = scaler.fit_transform(
    sana[["Monthly Salary"]]
)

# Display the DataFrame
print(sana)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 sana["Monthly Salary"] = scaler.fit_transform(sana[["Monthly Salary"]])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     892         warnings.warn(
# ...

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Fill null values using mean
sana.fillna(sana.mean(numeric_only=True), inplace=True)

# Replace infinity values with NaN (if any)
sana.replace([np.inf, -np.inf], np.nan, inplace=True)

# Again fill any new NaN values created above
sana.fillna(sana.mean(numeric_only=True), inplace=True)

# Standard Scaling
scaler = StandardScaler()
sana["Monthly Salary"] = scaler.fit_transform(sana[["Monthly Salary"]])

print(sana)
# Out:
#    Employee_ID            Name        Age  Gender   Department  \
# 0       EMP001    Rajesh Kumar  32.000000    Male  Engineering
# 1       EMP002    Priya Sharma  28.000000  Female    Marketing
# 2       EMP003      Amit Singh  35.000000    Male      Finance
# 3       EMP004     Sneha Patel  26.000000  Female           IT
# 4       EMP005    Vikram Reddy  40.000000    Male  Engineering
# 5       EMP006      Kavya Nair  29.000000  Female        Sales
# 6       EMP007     Arjun Gupta  31.000000    Male  Engineering
# 7       EMP008     Meera Joshi  27.000000  Female       Design
# 8       EMP009   Rohit Agarwal  33.000000    Male      Finance
# 9       EMP010     Anita Verma  38.000000  Female           HR
# 10      EMP011     Suresh Iyer  42.000000    Male  Engineering
# 11      EMP012  Pooja Malhotra  32.914894  Female    Marketing
# 12      EMP013    Karan Chopra  30.000000    Male        Sales
# 13      EMP014       Divya Rao  34.000000  Female  Engineering
# ...
